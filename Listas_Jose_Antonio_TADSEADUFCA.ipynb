# %% [markdown]
# # LISTA 1 - APLICANDO CONCEITOS BÁSICOS (PSEUDOCODIGO)
#
#
#
#
# 1. Faça um algoritmo que receba dois números e exiba o resultado da sua soma.
#
#
#
# ```
# numero1 = int (input("Insira o primeiro número "))
# numero2 = int (input("Insira o segundo número "))
#
# soma = numero1 + numero2
#
# print("A soma dos número é: ", soma)
# ```
#
#
#
#
# 2. Faça um algoritmo que receba dois números e ao final mostre a soma, subtração, multiplicação e a
# divisão dos números lidos.
#
#
#
# ```
# numero1 = int (input("Insira o primeiro número "))
# numero2 = int (input("Insira o segundo número "))
#
# soma = numero1 + numero2
# subtracao = numero1 - numero2
# multiplicacao = numero1 * numero2
# divisão = numero1 / numero2
#
# print("Soma: ", soma )
# print("Substração: ", subtracao)
# print("Multiplicação: ", multiplicacao)
# print("Divisão ", divisão)
# ```
#
#
#
# 3. Escrever um algoritmo para determinar o consumo médio de um automóvel sendo fornecida a
# distância total percorrida pelo automóvel e o total gasto de combustível.
#
#
# ```
# distancia = int (input("Insira a distância em km "))
# combustivel = int (input("Insira a quantidade de combustível em m³ "))
# consumo = distancia/combustivel
#
# print("A distância percorrida de : ", distancia , "km")
# print("O gasto de combustível foi de: ", combustivel,"km/m³")
# print("O consumo foi de : ",consumo,"km/m³")
#
# ```
#
#
# 4. Escrever um algoritmo que leia o nome de um vendedor, o seu salário fixo, e o total de vendas
# efetuadas por ele no mês (em dinheiro). Sabendo que este vendedor ganha 15% de comissão sobre
# suas vendas efetuadas, informar o seu nome, o salário fixo e o salário ao final do mês.
#
# ```
# '''  Escrever um algoritmo que leia o nome de um vendedor, o seu salário fixo, e o total de vendas
# efetuadas por ele no mês (em dinheiro). Sabendo que este vendedor ganha 15% de comissão sobre
# suas vendas efetuadas, informar o seu nome, o salário fixo e o salário ao final do mês.'''
#
# vendedor = "Jose"
# salario = 1302
# vendas = 20000
# comissao = vendas*0.15
# salariocomissao = comissao+salario
#
# print(vendedor," salário fixo de: R$",salario," salário com comissão: R$", salariocomissao)
# ```
#
# 5. Escrever um algoritmo que leia o nome de um aluno e as notas das três provas que ele obteve no
# semestre. No final informar o nome do aluno e a sua média (aritmética)
#
# ```
# aluno = "Jose"
# nota1 = 9
# nota2 = 10
# nota3 = 8
# media = (nota1+nota2+nota3)/3
#
# print("Aluno: ",aluno,"e média das notas será: ", media)
#
# ```
#
# 6. Ler dois valores A e B, e efetuar a troca dos valores de forma que a variável A passe a possuir o
# valor da variável B, e a variável B passe a possuir o valor da variável A. Apresentar os valores
# trocados.
#
# ```
# A = 25
# B = 50
# print("Valor de A = ", A ,"Valor de B = ", B)
#
# C = B
# B = A
# A = C
# print("Valor de A = ", A ,"Valor de B = ", B)
# ```
#
# 7. Elaborar um algoritmo que efetue a apresentação do valor da conversão em real (R$) de um valor
# lido em dólar (US$). O algoritmo deverá solicitar o valor da cotação do dólar e também a
# quantidade de dólares disponíveis com o usuário.
#
# ```
# dolar = float (input("Insira a quantidade em dolar "))
# dolarCotacao = float (input("Insira o valor da cotacao do dolar "))
# converterReal = dolarCotacao * dolar
#
# print("Valor de dólares em real ", converterReal)
# ```
#
# 8. Ler uma temperatura em graus Celsius e apresentá-la convertida em graus Fahrenheit. A formula
# de conversão e: Fa = 9/5 * Ca + 32, sendo Fa temperatura em Fahrenheit e Ca temperatura em
# Celsius.
#
# ```
# celsius = 30
# fahrenheit =( (9/5) * celsius )+ 32
#
# print("A temperatura celsius de: ", celsius, " convertida em fahrenheit ",fahrenheit)
#
# ```
#
# 9. Faça um algoritmo que receba o preço de custo de um produto e mostre o valor de venda. Sabe-se
# que o preço de custo recebera um acréscimo de acordo com um percentual informado pelo
# usuário.
#
# ```
# produto = float(input("Insira o custo do produto: "))
# percentualVenda = float(input("Insira o percentual de venda: "))
# valorProduto = (percentualVenda/100) * produto
# print(valorProduto + produto)
#
# ```
#
# 10. A XPTO está vendendo seus produtos em 5 (cinco) prestações sem juros. Faça um algoritmo que
# receba um valor de uma compra e mostre o valor das prestações.
#
# ```
# produto = float(input("Insira o custo do produto: "))
# produtoDivido = produto/5
#
# print("O valor do produto: R$",produto," O valor das prestações: R$ ", produtoDivido)
#
# ```

# %% [markdown]
# # LISTA 2 - APLICANDO CONCEITOS DAS
# # ESTRUTURAS DE CONDIÇÃO
#
# 1. Faça um programa que receba três notas de um aluno, calcule e mostre a média aritmética e a
# mensagem que segue a tabela abaixo. Para alunos de exame, calcule e mostre a nota que devera
# ser tirada no exame para aprova9iio, considerando que a média no exame e 6,0.
#
#
#
# ```
# nota1 = float(input("Insira a primeira nota"))
# nota2 = float(input("Insira a segunda nota"))
# nota3 = float(input("Insira a terceira nota"))
# media = (nota1+nota2+nota3)/3
# if media >=0 and media < 3 :
#   print(f"Reprovado! Nota: {media}")
# elif media >= 3 and media < 7 :
#   print("Recuperação, nota: ", media)
#   recuperacao = 12 - media
#   print("Nota para conseguir recuperar: ", recuperacao)
# else:
#   print("Aprovado com nota: ", media)
# ```
#
#
#
#
# 2. Faça um programa que receba dois números e mostre o maior.
#
#
# ```
# x = float(input("Insira o valor de X  "))
# y = float(input("Insira o valor de Y "))
#
# if x > y :
#   print(f"X é maior e seu valor é:  {x}")
# else:
#   print(f"Y é maior e seu valor é:  {y}")
# ```
#
#
# 3. Faça um programa que receba três números e mostre-os em ordem crescente.
#
#
# ```
# x = float(input("Insira o valor de X  "))
# y = float(input("Insira o valor de Y "))
# z = float(input("Insira o valor de Z "))
#
# numeros = [x,y,z]
#
#
# numeros.sort()
#
# print(f"Os números em ordem crescente são: {numeros}")
#
# ```
#
#
# 4. Faça um programa que receba três números obrigatoriamente em ordem crescente e um quarto número que não siga esta regra. Mostre, em seguida, os quatro números em ordem decrescente.
#
# ```
# x = float(input("Insira o valor de X  "))
# y = float(input("Insira o valor de Y "))
# z = float(input("Insira o valor de Z "))
# w = float(input("Insira o valor de W "))
#
# numeros = [x, y, z, w]
#
# numeros.sort(reverse=True)
#
# print(f"Os números em ordem decrescente são: {numeros}")
#
# ```
#
# 5. Faça um programa que receba o dia o mês e o ano e mostre nos seguintes formatos: dia/mês/ano -
# mês por extenso. (ex: 19/03/2020 -> 19 de março de 2020).
#
# ```
# dia = input("Digite o dia: ")
# mes = input("Digite o mes: ")
# ano = input("Digite o ano: ")
#
# numerosExtenso = {
#     '01': 'janeiro',
#     '02': 'fevereiro',
#     '03': 'março',
#     '04': 'abril',
#     '05': 'maio',
#     '06': 'junho',
#     '07': 'julho',
#     '08': 'agosto',
#     '09': 'setembro',
#     '10': 'outubro',
#     '11': 'novembro',
#     '12': 'dezembro'
# }
#
#
# dataFormato1 = f"{dia}/{mes}/{ano}"
#
#
# mesExtenso = numerosExtenso.get(mes, 'mês inválido')
# dataFormato2 = f"{dia} de {mesExtenso} de {ano}"
#
#
# print(f"Data no formato dia/mês/ano: {dataFormato1}")
# print(f"Data com o mês por extenso: {dataFormato2}" )
# ```
#
# 6. Faça um programa que receba o código correspondente ao cargo de um funcionário e seu salário
# atual e mostre o cargo, o valor do aumento e seu novo salário. Os cargos estão na tabela a seguir:
#
# ```
# codigoCargo = int(input("Digite o código do cargo (1 a 5): "))
# salarioAtual = float(input("Digite o salário atual: R$ "))
#
# if codigoCargo == 1:
#     cargo = "Escrituário"
#     aumentoPercentual = 50
# elif codigoCargo == 2:
#     cargo = "Secretário"
#     aumentoPercentual = 35
# elif codigoCargo == 3:
#     cargo = "Caixa"
#     aumentoPercentual = 20
# elif codigoCargo == 4:
#     cargo = "Gerente"
#     aumentoPercentual = 10
# elif codigoCargo == 5:
#     cargo = "Diretor"
#     aumentoPercentual = 0
# else:
#     print("Código de cargo inválido!")
#     exit(1)
#
# aumento = salarioAtual * aumentoPercentual / 100
# novoSalario = salarioAtual + aumento
#
# print(f"Cargo: {cargo}")
# print("Valor do aumento: R$ {:.2f}".format(aumento))
# print("Novo salário: R$ {:.2f}".format(novoSalario))
# ```
#
# 7. Faça um programa que receba o salário de um funcionário, calcule e mostre o novo salário desse
# funcionário, acrescido de bonificação e de auxílio-escola.
#
# ```
# salarioAtual = float(input("Digite o salário atual: R$ "))
#
# if salarioAtual <= 500:
#     bonificacao = salarioAtual * 0.05
# elif salarioAtual <= 1200:
#     bonificacao = salarioAtual * 0.12
# else:
#     bonificacao = 0
#
# if salarioAtual <= 600:
#     auxilioEscola = 150
# else:
#     auxilioEscola = 100
#
# novoSalario = salarioAtual + bonificacao + auxilioEscola
#
# print("Novo salário: R$ {:.2f}".format(novoSalario))
# ```
#
# 8. Faça um programa para resolver equações do 2º. grau. (utilize a função RAIZ para a raiz quadrada)
#
# ```
# import math
#
# a = float(input("Digite o coeficiente 'a' da equação: "))
# b = float(input("Digite o coeficiente 'b' da equação: "))
# c = float(input("Digite o coeficiente 'c' da equação: "))
#
#
# delta = (b*b) - (4*a*c)
#
# if delta < 0:
#     print("A equação não possui raízes reais.")
# else:
#     raiz1 = (-b + math.sqrt(delta)) / (2*a)
#     raiz2 = (-b - math.sqrt(delta)) / (2*a)
#
#     print("Raiz 1: {:.2f}".format(raiz1))
#     print("Raiz 2: {:.2f}".format(raiz2))
#
# ```
#
# 9. Dados três valores X, Y e Z, verificar se eles podem ser os comprimentos dos lados de um triângulo
# e, se forem, verificar se o um triângulo equilátero, isósceles ou escaleno. Se eles não formarem um
# triângulo escrever uma mensagem. Considerar que:
# • o comprimento de cada lado de um triângulo é menor que a soma dos outros dois lados:
# • chama-se triângulo equilátero o triângulo que tem três lados iguais;
# • chama-se triângulo isósceles o triângulo que tem o comprimento de dois lados iguais;
# • chama-se triângulo escaleno o triângulo que tem os três lados diferentes.
#
# ```
# x = float(input("Digite o valor do lado X do triângulo: "))
# y = float(input("Digite o valor do lado Y do triângulo: "))
# z = float(input("Digite o valor do lado Z do triângulo: "))
#
# if x + y > z and x + z > y and y + z > x:
#
#     if x == y and y == z:
#         print("É um triângulo equilátero.")
#     elif x == y or x == z or y == z:
#         print("É um triângulo isósceles.")
#     else:
#         print("É um triângulo escaleno.")
# else:
#     print("Os valores informados não formam um triângulo.")
# ```
#
# 10. Faça um programa que receba:
# • o código de um produto comprado, supondo que a digitação do código do produto seja sempre
# válida, ou seja, um número inteiro entre l e 10;
# • o peso do produto em quilos;
# • o código do país de origem, supondo que a digitação do código do país seja sempre válida, ou
# seja, um número inteiro entre 1 e 3.
# Calcule e mostre:
# • O peso do produto convertido em gramas.
# • O preço total do produto comprado.
# • O valor do imposto, sabendo-se que ele é cobrado sobre o preço total do produto comprado e
# depende do país de origem.
# • O valor total, preço total do produto mais imposto.
#
# ```
# codigoProduto = int(input("Digite o código do produto (1 a 10): "))
# pesoKilos = float(input("Digite o peso do produto em quilos: "))
# codigoPais = int(input("Digite o código do país de origem (1 a 3): "))
#
# pesoGramas = pesoKilos * 1000
#
# if codigoProduto >= 1 and codigoProduto <= 4:
#     precoGrama = 10
# elif codigoProduto >= 5 and codigoProduto <= 7:
#     precoGrama = 25
# else:
#     precoGrama = 35
#
#
# precoTotal = pesoGramas * precoGrama
#
# if codigoPais == 1:
#     imposto = 0
# elif codigoPais == 2:
#     imposto = precoTotal * 0.15
# else:
#     imposto = precoTotal * 0.25
#
# valorTotal = precoTotal + imposto
#
# print("Peso do produto em gramas:", pesoGramas)
# print("Preço total do produto: R$", precoTotal)
# print("Valor do imposto: R$", imposto)
# print("Valor total a ser pago: R$", valorTotal)
# ```
